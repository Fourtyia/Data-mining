# %% [markdown]
# <a href="https://colab.research.google.com/github/Fourtyia/Data-mining/blob/main/Dataset_Fourtyia_Arteuary_231011402124_04TPLP031.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data1 = pd.read_csv("DoS ICMP Flood.csv")

# %%
data1
# Out:
#                                         Flow ID           Src IP  Src Port  \
# 0      192.168.137.174-52.33.155.26-46488-443-6  192.168.137.174     46488
# 1      192.168.137.250-34.122.121.32-53298-80-6  192.168.137.250     53298
# 2     192.168.137.174-35.224.21.224-51040-443-6  192.168.137.174     51040
# 3     192.168.137.174-35.224.21.224-51040-443-6  192.168.137.174     51040
# 4       192.168.137.174-34.173.20.6-35812-443-6  192.168.137.174     35812
# ...                                         ...              ...       ...
# 2102           10.0.0.9-10.0.0.254-45455-1883-6         10.0.0.9     45455
# 2103           10.0.0.9-10.0.0.254-35905-1883-6         10.0.0.9     35905
# 2104           10.0.0.8-10.0.0.254-43951-1883-6         10.0.0.8     43951
# 2105           10.0.0.6-10.0.0.254-35017-1883-6         10.0.0.6     35017
# 2106           10.0.0.6-10.0.0.254-44133-1883-6         10.0.0.6     44133
#
#              Dst IP  Dst Port  Protocol               Timestamp  \
# ...

# %%
data2 = pd.read_csv("MITM ARP Spoofing.csv")

# %%
data2
# Out:
#                                           Flow ID          Src IP  Src Port  \
# 0       142.251.41.42-192.168.137.210-443-46054-6   142.251.41.42       443
# 1     44.235.194.199-192.168.137.233-8883-40697-6  44.235.194.199      8883
# 2         34.173.20.6-192.168.137.174-443-60244-6     34.173.20.6       443
# 3         34.173.20.6-192.168.137.174-443-60244-6     34.173.20.6       443
# 4          3.162.3.14-192.168.137.210-443-43490-6      3.162.3.14       443
# ...                                           ...             ...       ...
# 1048     35.171.10.11-192.168.137.210-443-39344-6    35.171.10.11       443
# 1049  74.125.202.206-192.168.137.174-8883-60738-6  74.125.202.206      8883
# 1050      34.173.20.6-192.168.137.174-443-60242-6     34.173.20.6       443
# 1051      34.173.20.6-192.168.137.174-443-60242-6     34.173.20.6       443
# 1052  44.235.194.199-192.168.137.233-8883-40697-6  44.235.194.199      8883
#
# ...

# %%
data3 = pd.read_csv("Recon Ping Sweep.csv")

# %%
data3
# Out:
#                                        Flow ID           Src IP  Src Port  \
# 0             10.0.0.8-10.0.0.254-43083-1883-6         10.0.0.8     43083
# 1             10.0.0.1-10.0.0.254-43839-1883-6         10.0.0.1     43839
# 2             10.0.0.6-10.0.0.254-35017-1883-6         10.0.0.6     35017
# 3   192.168.137.174-64.233.181.206-43128-443-6  192.168.137.174     43128
# 4      192.168.137.174-34.173.20.6-34922-443-6  192.168.137.174     34922
# ..                                         ...              ...       ...
# 66           10.0.0.13-10.0.0.254-35153-1883-6        10.0.0.13     35153
# 67           10.0.0.10-10.0.0.254-42969-1883-6        10.0.0.10     42969
# 68           10.0.0.15-10.0.0.254-40499-1883-6        10.0.0.15     40499
# 69     192.168.137.174-34.173.20.6-34920-443-6  192.168.137.174     34920
# 70     34.173.20.6-192.168.137.174-443-34920-6      34.173.20.6       443
#
#              Dst IP  Dst Port  Protocol               Timestamp  \
# ...

# %%
mengabungkan =pd.concat([data1,data2,data3],ignore_index=True)

# %%
mengabungkan.columns.values
# Out:
# array(['Flow ID', 'Src IP', 'Src Port', 'Dst IP', 'Dst Port', 'Protocol',
#        'Timestamp', 'Flow Duration', 'Total Fwd Packet',
#        'Total Bwd packets', 'Total Length of Fwd Packet',
#        'Total Length of Bwd Packet', 'Fwd Packet Length Max',
#        'Fwd Packet Length Min', 'Fwd Packet Length Mean',
#        'Fwd Packet Length Std', 'Bwd Packet Length Max',
#        'Bwd Packet Length Min', 'Bwd Packet Length Mean',
#        'Bwd Packet Length Std', 'Flow Bytes/s', 'Flow Packets/s',
#        'Flow IAT Mean', 'Flow IAT Std', 'Flow IAT Max', 'Flow IAT Min',
#        'Fwd IAT Total', 'Fwd IAT Mean', 'Fwd IAT Std', 'Fwd IAT Max',
#        'Fwd IAT Min', 'Bwd IAT Total', 'Bwd IAT Mean', 'Bwd IAT Std',
#        'Bwd IAT Max', 'Bwd IAT Min', 'Fwd PSH Flags', 'Bwd PSH Flags',
#        'Fwd URG Flags', 'Bwd URG Flags', 'Fwd Header Length',
#        'Bwd Header Length', 'Fwd Packets/s', 'Bwd Packets/s',
#        'Packet Length Min', 'Packet Length Max', 'Packet Length Mean',
# ...

# %%
x = mengabungkan.iloc[:,7: 76]

# %%
x
# Out:
#       Flow Duration  Total Fwd Packet  Total Bwd packets  \
# 0           1415686                43                 25
# 1            997485                 5                  4
# 2            327907                15                  0
# 3                 0                 2                  0
# 4          86263581                14                 11
# ...             ...               ...                ...
# 3226       60005447                 5                  4
# 3227       61046329                 6                  6
# 3228       60004153                 5                  4
# 3229       60412824                17                 16
# 3230              5                 2                  0
#
#       Total Length of Fwd Packet  Total Length of Bwd Packet  \
# 0                        45159.0                      6094.0
# 1                           87.0                       148.0
# 2                         5429.0                         0.0
# ...

# %%
y =mengabungkan.iloc[:,83: 84]

# %%
y
# Out:
#            Attack Name
# 0       DoS ICMP Flood
# 1       DoS ICMP Flood
# 2       DoS ICMP Flood
# 3       DoS ICMP Flood
# 4       DoS ICMP Flood
# ...                ...
# 3226  Recon Ping Sweep
# 3227  Recon Ping Sweep
# 3228  Recon Ping Sweep
# 3229  Recon Ping Sweep
# 3230  Recon Ping Sweep
#
# [3231 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size = 0.2, random_state = 42)

# %%
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier

# %%
asep = DecisionTreeClassifier(criterion='entropy', splitter ='random')
asep.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', splitter='random')

# %%
y_pred = asep.predict(x_test)

# %%
y_pred
# Out:
# array(['DoS ICMP Flood', 'DoS ICMP Flood', 'DoS ICMP Flood',
#        'MITM ARP Spoofing', 'DoS ICMP Flood', 'DoS ICMP Flood',
#        'DoS ICMP Flood', 'DoS ICMP Flood', 'DoS ICMP Flood',
#        'DoS ICMP Flood', 'MITM ARP Spoofing', 'DoS ICMP Flood',
#        'DoS ICMP Flood', 'DoS ICMP Flood', 'DoS ICMP Flood',
#        'DoS ICMP Flood', 'Recon Ping Sweep', 'DoS ICMP Flood',
#        'DoS ICMP Flood', 'DoS ICMP Flood', 'DoS ICMP Flood',
#        'DoS ICMP Flood', 'MITM ARP Spoofing', 'MITM ARP Spoofing',
#        'MITM ARP Spoofing', 'DoS ICMP Flood', 'MITM ARP Spoofing',
#        'MITM ARP Spoofing', 'DoS ICMP Flood', 'DoS ICMP Flood',
#        'DoS ICMP Flood', 'DoS ICMP Flood', 'DoS ICMP Flood',
#        'DoS ICMP Flood', 'DoS ICMP Flood', 'DoS ICMP Flood',
#        'DoS ICMP Flood', 'MITM ARP Spoofing', 'MITM ARP Spoofing',
#        'DoS ICMP Flood', 'DoS ICMP Flood', 'DoS ICMP Flood',
#        'DoS ICMP Flood', 'DoS ICMP Flood', 'MITM ARP Spoofing',
# ...

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test,y_pred)

# %%
accuracy

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
fig = plt.figure(figsize = (10,7))
tree.plot_tree(asep, feature_names =x.columns.values, class_names = np.array(['Dos ICMP FLood','MITM ARP Spoofing','Recon Ping Sweep']), filled= True)
plt.show()
